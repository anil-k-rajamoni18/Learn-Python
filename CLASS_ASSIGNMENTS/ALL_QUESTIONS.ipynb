# %% [markdown]
# ## Print()
#
#
# 1. Let's start with a long time programming tradition and print "Hello World!" by typing it inside print() function.
#
# ```python
# # Replace "type here" on line 2 with "Hello World!"
# print("type here")
# ```
#
# 2. try to assign "Hello World!" to the variable my_text.
#
# ```python
# # You can assign "Hello World!" to the variable below
#
# my_text=""
# print(my_text)
#
# ```
#
# 3. There are many ways to concetenate different data pieces with Python's print() function. Here is one of them. Take a look!
#
# ```python
# # Type a couple of different values inside the print function. Make sure they are separated by commas.
#
# print("")
#
# ```

# %% [markdown]
# ## Variables
#
# 1. Declare five realtime variables of different types(int,float,bool,string,complex,None) print type, id, value in newline.
#
# 2. Guess the output of following
#  ```python
#
# name = "John"
# age = 25
# salary = 25800.60
# skills = ('c','java','ruby')
# print(name, type(name))
# print(age, type(age))
# print(salary, type(salary))
# print(skills, type(skills))
# ```
#
#
# 3. Guess the output of the following code snippet
# ```python
#
# mission = 'chandrayaan-3'
#
# print(mission)
#
# print(mission[0])
# print(mission[2:5])
# print(len(mission))
# print(mission[13])
# print(mission + " TEST")
# ```
#
# 4. What is the data type of the variable
#
# ```python
# languages = 'c','cpp','java','python'
# print(languages, type(languages))
# ```

# %% [markdown]
# ## Input()
#
# 1. Read two integers and do the following opertions
#     - addition
#     - subtraction
#     - modulus
#     - integer division
#
# 2. Read a list of student marks of integer type , calculate average
# 3. Read a list of employees salaries and calculate annual package income.

# %% [markdown]
# ## Data Type
#
# 1.
# ```python
# #Assign an integer to the variable, then print it.
#
# men_stepped_on_the_moon=
# print()
#
# ```
#
# 2.
# ```python
# #Type a couple of words or a short sentence for your variable, then print it.
#
# my_reason_for_coding=
# print()
#
# ```
#
# 3.
# ```python
# #Assign a float with 2 decimals to the variable below.
#
# global_mean_sea_level_2018=21
#
# #Type your code here.
# global_mean_sea_level_2018=
#
#
# print(global_mean_sea_level_2018)
# ```
#
# 4.
# ```python
# #Assign True or False to the variable below then print it.
#
# staying_alive=
# print(staying_alive)
#
# ```
#
# 5.
# ```python
# #Create a gift_list list and assign type to answer_1 variable
#
# gift_list=
#
# answer_1=
#
# print(answer_1)
# ```
#
# 6.
#
# ```python
# #Create a grocery_items dictionary and assign its type to answer_2 variable
#
# grocery_items=
#
# answer_2=
#
# print(answer_2)
# ```
#
# 7.
# ```python
# #Create a bucket_list tuple and assign its type to answer_3 variable
#
# bucket_list=
#
# answer_3=
#
# print(answer_3)
#
# ```

# %% [markdown]
# ### Basic Questions
#
# 1. Write a Python program to find out what version of Python you are using
#
# 2. Write a Python program to display the current date and time.
# ```python
# Sample Output :
# Current date and time :
# 2010-07-05 14:34:14
#
# ```
#
# 3.Write a Python program that accepts the user's first and last name and prints them in reverse order with a space between them.
#
#
# 4. Write a Python program that accepts a sequence of comma-separated numbers from the user and generates a list and a tuple of those numbers.
# ```python
# Sample data : 3, 5, 7, 23
# Output :
# List : ['3', ' 5', ' 7', ' 23']
# Tuple : ('3', ' 5', ' 7', ' 23')
# ```
#
# 5.Write a Python program that accepts a filename from the user and prints the extension of the file.
# ```python
# Sample filename : abc.java
# Output : java
# ```
#
# 6. Write a Python program to display the examination schedule. (extract the date from exam_st_date).
# ```python
# exam_st_date = (11, 12, 2014)
# Sample Output : The examination will start from : 11 / 12 / 2014
#
# ```
#
# 7.Write a Python program that accepts an integer (n) and computes the value of n+nn+nnn.
# ```python
# Sample value of n is 5
# Expected Result : 615
#
#  ````
#
#
# 8. Write a Python program to print the documents (syntax, description etc.) of Python built-in function(s).
#
# ```python
# Sample function: abs()
#
#  ```
#
#
#  9.  Write a Python program that prints out all colors from color_list_1 that are not present in color_list_2.
#
# Test Data :
# ```python
# color_list_1 = set(["White", "Black", "Red"])
# color_list_2 = set(["Red", "Green"])
# Expected Output :
# {'Black', 'White'}
#
# ```
#
#
# 10. Write a Python program to solve (x + y) * (x + y).
# ```python
# Test Data : x = 4, y = 3
# Expected Output : (4 + 3) ^ 2) = 49
#
# ```
#
#
# 11. Write a Python program to add leading zeroes to a string.
# ```python
# Sample Input
# inputStr = "Hello"
# numOfZeros = 3
# trailing zeros : "Hello000"
# leading zeros = "000Hello"
# ```
